# %%
from bs4 import BeautifulSoup
import requests
import os

# %%
url = r"https://codingblocks.com/"

# %%
result = requests.get(url)

# %%
result.status_code

# %%
soup = BeautifulSoup(result.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all("h1")
# Out:
# [<h1 class="uppercase mb16">Live Courses</h1>,
#  <h1 class="uppercase mb16">Classroom Courses</h1>,
#  <h1 class="uppercase mb16">Online Courses</h1>,
#  <h1 class="uppercase mb16">Our Team</h1>]

# %%
img_tags = soup.find_all("img") #for finding all images

# %%
img_tags #this is giving all the info about image  but we want only source i.e src info
# Out:
# [<img height="1" src="https://www.facebook.com/tr?id=1947467048859851&amp;ev=PageView
#      &amp;noscript=1" width="1"/>,
#  <img height="1" src="https://q.quora.com/_/ad/0e6543f4ed0047658c67c5d04a8ace8d/pixel?tag=ViewContent&amp;noscript=1" style="display:none" width="1"/>,
#  <img alt="Foundry" class="logo logo-light" src="/assets/images/logo-light.png"/>,
#  <img alt="Foundry" class="logo logo-dark" src="/assets/images/cb/cblogo.png"/>,
#  <img alt="" class="background-image" src="assets/images/cb/cover/live_class_banner.jpg"/>,
#  <img alt="" class="background-image" src="assets/images/cb/cover/summer_batches.jpg"/>,
#  <img alt="" class="background-image" src="assets/images/cb/cover/online_banner.jpg"/>,
#  <img alt="" class="background-image" src="assets/images/cb/cover/cover5.jpg"/>,
#  <img alt="" class="background-image" src="assets/images/cb/cover/cast.jpg"/>,
#  <img alt="" class="course logo" src="assets/images/cb/logosc/color_cpp.svg"/>,
# ...

# %%
img_tags[0].get("src")
 # as we see in the output we got the src url but parser is not functioning properly as we see a '\n' in url
# Out:
# 'https://www.facebook.com/tr?id=1947467048859851&ev=PageView\n    &noscript=1'

# %%
for img_tag in img_tags:
    print(img_tag.get("src")) #will give us all the src
# Out:
# https://www.facebook.com/tr?id=1947467048859851&ev=PageView
#     &noscript=1
# https://q.quora.com/_/ad/0e6543f4ed0047658c67c5d04a8ace8d/pixel?tag=ViewContent&noscript=1
# /assets/images/logo-light.png
# /assets/images/cb/cblogo.png
# assets/images/cb/cover/live_class_banner.jpg
# assets/images/cb/cover/summer_batches.jpg
# assets/images/cb/cover/online_banner.jpg
# assets/images/cb/cover/cover5.jpg
# assets/images/cb/cover/cast.jpg
# assets/images/cb/logosc/color_cpp.svg
# assets/images/cb/logosc/color_java.svg
# assets/images/cb/logosc/color_nodejs.svg
# https://minio.codingblocks.com/amoeba/0ee7474c-de3c-44d7-a704-646491c702e8.svg
# assets/images/cb/logosc/color_java.svg
# assets/images/cb/logosc/color_cp.svg
# assets/images/cb/logosc/color_algo.svg
# assets/images/cb/logosc/color_cpp.svg
# assets/images/cb/logosc/color_algo.svg
# assets/images/cb/logosc/color_java.svg
# assets/images/cb/logosc/color_java.svg
# assets/images/cb/logosc/color_python.svg
# ...

# %%
set_urls = set()
for img_tag in img_tags:
    member_url= img_tag.get("src")
    if "team" in member_url:
      set_urls.add(member_url)

# %%
#We have defined a set to store the urls avoid repetition in urls.these are urls with word 'team'. these are not complete urls.

# %%
def save_img(url,dest):
    result=requests.get(url)
    if result.status_code== 200:
        with open(dest,"wb") as photo:
            photo.write(result.content) #saving the image in a destination folder made below by os.mkdir

# %%
if not os.path.exists("photos"):
    os.mkdir("photos")
for location in set_urls:
    total= url + location
    file_name= location.split("/")[-1]
    save_img(total,"photos/"+file_name) #making of complete url by adding the initial url + the set_url aka location.

# %%
#the os.mkdir creates a folder file to to direct all the photos and store them sequencially.
